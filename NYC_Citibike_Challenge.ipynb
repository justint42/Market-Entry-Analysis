# %%
import pandas as pd

# %%
citibike_NYC_201908_df = pd.read_csv("../bikesharing/201908-citibike-tripdata.csv")

# %%
citibike_NYC_201908_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id           float64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id             float64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
citibike_NYC_201908_df['tripduration'] = pd.to_datetime(citibike_NYC_201908_df['tripduration'], unit='s')

# %%
citibike_NYC_201908_df.dtypes
# Out:
# tripduration               datetime64[ns]
# starttime                          object
# stoptime                           object
# start station id                  float64
# start station name                 object
# start station latitude            float64
# start station longitude           float64
# end station id                    float64
# end station name                   object
# end station latitude              float64
# end station longitude             float64
# bikeid                              int64
# usertype                           object
# birth year                          int64
# gender                              int64
# dtype: object

# %%
citibike_NYC_201908_df.head(10)
# Out:
#          tripduration                 starttime                  stoptime  \
# 0 1970-01-01 00:06:33  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1 1970-01-01 00:10:27  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2 1970-01-01 00:18:52  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3 1970-01-01 00:29:40  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4 1970-01-01 00:25:17  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
# 5 1970-01-01 00:10:32  2019-08-01 00:00:11.8060  2019-08-01 00:10:43.9590
# 6 1970-01-01 00:01:57  2019-08-01 00:00:18.2010  2019-08-01 00:02:15.8600
# 7 1970-01-01 00:06:18  2019-08-01 00:00:22.0840  2019-08-01 00:06:40.9350
# 8 1970-01-01 00:18:22  2019-08-01 00:00:22.0870  2019-08-01 00:18:44.3890
# 9 1970-01-01 00:28:53  2019-08-01 00:00:22.5580  2019-08-01 00:29:15.9080
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# ...

# %%
citibike_NYC_201908_df.to_csv("../bikesharing/201908_cb_NYC_tripdata_updated.csv", index=False)
